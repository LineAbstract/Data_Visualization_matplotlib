# %% [markdown]
# ## Visualizing Data with Pandas and MatPlotLib

# %% [markdown]
# ### As a Data Analyst, I want to set up the proper imports so I have access to the Pandas and MatPlotLib libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### As a Data Analyst, I want to import and store the `ufo_sightings.csv` file in a variable

# %%
df = pd.read_csv('ufo_sightings.csv', index_col='#')

df
# Out:
#               Date_Time                  City State/Province Country  \
# #
# 0      10/10/1949 20:30            San Marcos             TX      US
# 1      10/10/1949 21:00          Lackland Afb             TX     NaN
# 2      10/10/1955 17:00  Chester (Uk/England)            NaN      GB
# 3      10/10/1956 21:00                  Edna             TX      US
# 4      10/10/1960 20:00               Kaneohe             HI      US
# ...                 ...                   ...            ...     ...
# 65531   8/12/2011 23:15               Yonkers             NY      US
# 65532   8/12/2011 23:27            Mandeville             LA      US
# 65533   8/12/2012 00:00                 Davis             CA      US
# 65534   8/12/2012 00:00                Peoria             IL      US
# 65535   8/12/2012 00:15                Barron             WI      US
#
#        UFO_Shape  Length_of_Encounter Described_Duration  \
# #
# 0       cylinder               2700.0         45 minutes
# ...

# %% [markdown]
# ### As a Data Analyst, I want to ensure my DataFrame is cleaned by removing any **null** values

# %%
# analysis of DF
df.info()
# currently there are 64683 entries
# it appears there are certainly NULL values in multiple
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64683 entries, 0 to 65535
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date_Time            64683 non-null  object
#  1   City                 64683 non-null  object
#  2   State/Province       59973 non-null  object
#  3   Country              56927 non-null  object
#  4   UFO_Shape            63124 non-null  object
#  5   Length_of_Encounter  64683 non-null  float64
#  6   Described_Duration   64683 non-null  object
#  7   Description          64668 non-null  object
#  8   Date_Documented      64683 non-null  object
#  9   Latitude             64683 non-null  float64
#  10  Longitude            64683 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 5.9+ MB

# %%
# removal of null values
nonnull_df = df.dropna()

nonnull_df.info()
# we have dropped our entry count to 53562 entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53562 entries, 0 to 65535
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date_Time            53562 non-null  object
#  1   City                 53562 non-null  object
#  2   State/Province       53562 non-null  object
#  3   Country              53562 non-null  object
#  4   UFO_Shape            53562 non-null  object
#  5   Length_of_Encounter  53562 non-null  float64
#  6   Described_Duration   53562 non-null  object
#  7   Description          53562 non-null  object
#  8   Date_Documented      53562 non-null  object
#  9   Latitude             53562 non-null  float64
#  10  Longitude            53562 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 4.9+ MB

# %%
# are there duplicates?
nonnull_df[nonnull_df.duplicated()]
# nonnull_df.duplicated().sort_values()

# no duplicates found in dataset 
nonnull_df
# Out:
#               Date_Time        City State/Province Country  UFO_Shape  \
# #
# 0      10/10/1949 20:30  San Marcos             TX      US   cylinder
# 3      10/10/1956 21:00        Edna             TX      US     circle
# 4      10/10/1960 20:00     Kaneohe             HI      US      light
# 5      10/10/1961 19:00     Bristol             TN      US     sphere
# 7      10/10/1965 23:45     Norwalk             CT      US       disk
# ...                 ...         ...            ...     ...        ...
# 65531   8/12/2011 23:15     Yonkers             NY      US      light
# 65532   8/12/2011 23:27  Mandeville             LA      US     sphere
# 65533   8/12/2012 00:00       Davis             CA      US    unknown
# 65534   8/12/2012 00:00      Peoria             IL      US     circle
# 65535   8/12/2012 00:15      Barron             WI      US  formation
#
#        Length_of_Encounter Described_Duration  \
# #
# 0                   2700.0         45 minutes
# ...

# %% [markdown]
# ### As a Data Analyst, I want to filter my DataFrame to remove any information that is not related to my analysis
# * This will include **dropping** the **Described_Duration, Description, and Date_Documented** columns

# %%
filtered_df = nonnull_df.drop(['Described_Duration', 'Description', 'Date_Documented'], axis=1)

filtered_df
# Out:
#               Date_Time        City State/Province Country  UFO_Shape  \
# #
# 0      10/10/1949 20:30  San Marcos             TX      US   cylinder
# 3      10/10/1956 21:00        Edna             TX      US     circle
# 4      10/10/1960 20:00     Kaneohe             HI      US      light
# 5      10/10/1961 19:00     Bristol             TN      US     sphere
# 7      10/10/1965 23:45     Norwalk             CT      US       disk
# ...                 ...         ...            ...     ...        ...
# 65531   8/12/2011 23:15     Yonkers             NY      US      light
# 65532   8/12/2011 23:27  Mandeville             LA      US     sphere
# 65533   8/12/2012 00:00       Davis             CA      US    unknown
# 65534   8/12/2012 00:00      Peoria             IL      US     circle
# 65535   8/12/2012 00:15      Barron             WI      US  formation
#
#        Length_of_Encounter   Latitude   Longitude
# #
# 0                   2700.0  29.883056  -97.941111
# ...

# %% [markdown]
# ### As a Data Analyst, I want to convert the `Date_Time` column to utilize Pandas' DateTime data type

# %%
filtered_df['Date_Time'] = pd.to_datetime(filtered_df['Date_Time'])

filtered_df.info()
# confirmed that we have changed the datatype of Date_Time to Pandas DateTime to datetime64[ns]
final_df = filtered_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53562 entries, 0 to 65535
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date_Time            53562 non-null  datetime64[ns]
#  1   City                 53562 non-null  object
#  2   State/Province       53562 non-null  object
#  3   Country              53562 non-null  object
#  4   UFO_Shape            53562 non-null  object
#  5   Length_of_Encounter  53562 non-null  float64
#  6   Latitude             53562 non-null  float64
#  7   Longitude            53562 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Data Visualization with Matplotlib

# %% [markdown]
# ### As a Data Analyst, I want to visualize the **frequency of different UFO shapes**, to determine which UFO shapes are most commonly encountered
# * I will use a **Bar Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
final_df['UFO_Shape'].value_counts(ascending=True).plot.bar(figsize=(12,6));
plt.title('Frequency of UFO Shape Sightings', fontsize=20);
plt.xlabel('UFO Shape', fontsize=14);
plt.xticks(rotation=30, horizontalalignment='center')
plt.ylabel('Number of Sightings', fontsize=14);

# %% [markdown]
# ### As a Data Analyst, I want to visualize the **number of UFO encounters**, grouped by each decade, to see if there is a correlation between number of sightings and decade
# * I will use a **Bar Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
final_df['Year Sighted'] = final_df['Date_Time'].dt.year
# final_df.head()
final_df['Decade Interval'] = (final_df['Year Sighted'] // 10) * 10
final_df['Decade Interval'].value_counts(ascending=True).sort_index().plot.bar(figsize=(6,3));
plt.title('Number of UFO Sightings by Decade', fontsize=20);
plt.xlabel('Decade', fontsize=14);
plt.xticks(rotation=30, horizontalalignment='center')
plt.ylabel('Number of Sightings', fontsize=14);

# %% [markdown]
# ### As a Data Analyst, I want to create a **Line Graph** to visualize the **Frequency of UFO sightings, by hour of the day**
# * I will use a **Line Graph** to visualize this data
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
final_df['Hour Sighted'] = final_df['Date_Time'].dt.hour
final_df['Hour Sighted'].value_counts(ascending=True).sort_index().plot.line(figsize=(6,3));
plt.xticks([0, 4, 8, 12, 16, 20, 24]);
plt.title('UFO Sightings by the Hour', fontsize=20);
plt.xlabel('Hour (24 Hour)', fontsize=14);
plt.ylabel('Number of Sightings', fontsize=14);

# %% [markdown]
# ### As a Data Analyst, I want to answer all questions in the following Markdown block to provide a **clear and detailed analysis of my UFO sighting findings**

# %% [markdown]
# 1. Which UFO shape is the most frequently reported?
#     * It appears that the most frequently reported description of a UFO is simply of a light.
#     * In terms of an actual shape, it's a triangle, followed closely by a circle.
#
# 2. Which shape is least frequently reported?
#     * The least frequently reported UFO shape is that of a cross.
#
# 3. Based on your analysis, what times of the day have the highest number of UFO sightings?
#     * The highest number of UFO sightings occur between 6pm and midnight with the peak being at 9pm.
#
# 4. Are there other factors that may account for this pattern in the data?
#     * Since the most frequently reported description of the UFO is it being a light, it would make sense that the largest concentration of sightings occur at night, where lights are more easily visible against the night sky.
#
# 5. Do you see any surprising trends in the breakdown by decade? Do you have any theories or ideas that may explain these patterns?
#     * I'm surprised to see a peak in the 2000's decade, however upon further analysis, it's apparent that the sightings increased in frequency in 2011, 2012 and 2013 over the previous years in the decade from 2000-2010, and then the sightings sharply dropped in 2014. This drop could be due to a lack of up to date data for the years 2014 and beyond. In terms of theories as to why there was a large increase in sightings, it could be due to increased air travel and increased satelites in orbit, leading reporters to believe it to be UFOs.
#
# 6. Based on your data analysis, what recommendation would you give to individuals interested in encountering a UFO?
#     * I'd suggest that individuals look at the night sky between the hours of 6pm and midnight, and especially so around 9pm. They ought to look for bright lights in the sky, triangles, circles, fireballs, spheres, disks and ovals.

# %% [markdown]
# ### **Bonus:** As a Data Analyst, I want to visualize the frequency of **different UFO shape sightings for Virginia, Wisconsin, and Tennessee**, to see if there is any variation of UFO shape frequency between states
# * I will use a **Stacked Bar Graph** to visualize this data
#     * I do not want to use a Stacked Bar Chart as it will not allow me to properly visualize the frequency of sightings accross multiple states to see a proper analysis of the shape variation of UFO sightings.
#     * I believe that a **Grouped Bar Chart** is a better tool for this task.
# * I will include a label for the X and Y axis
# * I will include a name for my chart

# %%
# manipulate va_df to have only the data we want
va_df = final_df[final_df['State/Province'] == 'VA']
va_df_stripped = va_df.drop(['Date_Time', 'City', 'Country', 'Length_of_Encounter', 'Latitude', 'Longitude', 'Year Sighted', 'Decade Interval', 'Hour Sighted'], axis=1)
# va_df_stripped
# va_df_stripped['UFO_Shape'].value_counts(ascending=True).sort_index().plot.bar(figsize=(6,3));

# manipulate wi_df to have only the data we want
wi_df = final_df[final_df['State/Province'] == 'WI']
wi_df_stripped = wi_df.drop(['Date_Time', 'City', 'Country', 'Length_of_Encounter', 'Latitude', 'Longitude', 'Year Sighted', 'Decade Interval', 'Hour Sighted'], axis=1)

# manipulate tn_df to have only the data we want
tn_df = final_df[final_df['State/Province'] == 'TN']
tn_df_stripped = tn_df.drop(['Date_Time', 'City', 'Country', 'Length_of_Encounter', 'Latitude', 'Longitude', 'Year Sighted', 'Decade Interval', 'Hour Sighted'], axis=1)

concat_df = pd.concat([va_df_stripped, wi_df_stripped, tn_df_stripped], axis=0)
print(concat_df.pivot(index='UFO_Shape', columns='State/Province', values='''unknown'''))
# plotdata = pd.DataFrame(va_df_stripped)
# plotdata.plot.bar()

# all_states = final_df[final_df['State/Province'] == 'VA'] | final_df[final_df['State/Province'] == 'WI'] | final_df[final_df['State/Province'] == 'TN']

# va_df['UFO_Shape'].value_counts().sort_index().plot.bar(figsize=(6,3))
# wi_df['UFO_Shape'].value_counts().sort_index().plot.bar(figsize=(6,3))
# tn_df['UFO_Shape'].value_counts().sort_index().plot.bar(figsize=(6,3))
# va_df['UFO_Shape'].value_counts(ascending=True).sort_index().plot.bar(figsize=(6,3))

# x = np.arange(len(final_df['UFO_Shape']))
# width = 0.25

# fig, ax = plt.subplots()
# bar1 = ax.bar(x-width/2, va_df, width, label='VA')
# bar2 = ax.bar(x-width/2, wi_df, width, label='WI')
# bar3 = ax.bar(x-width/2, tn_df, width, label='TN')

# va_df.plot.bar(x= 'UFO_Shape', figsize=(15,6))
# final_df.plot.bar()


# concat along rows
# vertical_concat = pd.concat([va_df, wi_df, tn_df], axis=0)
# vertical_concat['UFO_Shape'].value_counts().sort_index().plot.bar(figsize=(6,3))
# concat along columns
# horizontal_concat = pd.concat([va_df, wi_df, tn_df], axis=1)
# # horizontal_concat['UFO_Shape'].value_counts().sort_index().plot.bar(figsize=(6,3))

# display(vertical_concat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\remol\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\remol\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\remol\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unknown'
#
# ...
